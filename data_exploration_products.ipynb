# %%
import pandas as pd
pd.options.display.max_rows = 100
products = pd.read_csv('products.csv')

# %%
#sku – stock keeping unit: a unique identifier for each product
#name – product name
#desc – product description
#price – base price of the product, in euros
#promo_price – promotional price, in euros
#in_stock – whether or not the product was in stock at the moment of the data extraction
#type – a numerical code for product type

# %%
# price and promo_price are objects - should be floats

# %%
products.loc[products['sku'] == 'APP0025']
# Out:
#        sku                              name                    desc  price  \
# 2  APP0025  Mighty Mouse Apple Mouse for Mac  mouse Apple USB cable.   59.0
#
#    promo_price  in_stock  type  discount
# 2      569.898         0  1387  -510.898

# %%
products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
products.describe()
# Out:
#            in_stock
# count  19326.000000
# mean       0.109593
# std        0.312390
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
products['price'] = pd.to_numeric(products['price'], errors='coerce')
products['promo_price'] = pd.to_numeric(products['promo_price'], errors='coerce')

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        18849 non-null  float64
#  4   promo_price  6424 non-null   float64
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.0+ MB

# %%
products.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99      499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00      589.996
# 2                             mouse Apple USB cable.  59.00      569.898
# 3              IPhone dock and USB Cable Apple iPod.  25.00      229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.990
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %%
products.loc[products['promo_price'].isna()]
# Out:
#            sku                                               name  \
# 50     APP0367  Apple Mini DisplayPort to DVI Adapter Mac dual...
# 51     APP0344          Apple Thunderbolt Display 27 "Monitor Mac
# 66     MAK0008  Maclocks theft case iPad 2 3 and 4 black with ...
# 67     MAK0007  Maclocks theft case iPad 2 3 and 4 transparent...
# 97     MAK0014  Maclocks safety housing Kiosk iPad 2 3 and 4 b...
# ...        ...                                                ...
# 19300  REP0412                   Rear Camera Repair iPhone 7 Plus
# 19317  REP0403                             iPad LCD screen repair
# 19318  REP0402                           iPad touch screen repair
# 19319  KNO0032     Knomo MacBook Pro Beauchamp Backpack 14 "Black
# 19320  REP0076           repair Full screen iPad (1st generation)
#
#                                                     desc    price  \
# 50     Adapter Mini Display Port to DVI dual channel ...   119.00
# ...

# %%
products['discount'] = products['price'] - products['promo_price']
# Out:
# discount
#  0.000      139
#  359.000     58
#  669.000     57
#  552.010     57
#  909.010     57
#            ...
#  19.910       1
#  24.900       1
# -310.803      1
# -319.119      1
# -175.001      1
# Name: count, Length: 3036, dtype: int64

# %%
products.loc[products['discount'] < 0]
# Out:
#            sku                                            name  \
# 0      RAI0007               Silver Rain Design mStand Support
# 1      APP0023               Apple Mac Keyboard Keypad Spanish
# 2      APP0025                Mighty Mouse Apple Mouse for Mac
# 3      APP0072   Apple Dock to USB Cable iPhone and iPod white
# 5      APP0073  Apple Composite AV Cable iPhone and iPod white
# ...        ...                                             ...
# 19321  BEL0376         Belkin Travel Support Apple Watch Black
# 19322  THU0060    Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061     Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062      Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063    Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99      499.899
# ...

# %%
products['price'].max()
# Out:
# 15339.0

# %%
products['price'].min()
# Out:
# 2.99

# %%
products.duplicated().sum()
# Out:
# 8746

# %%
products.loc[products.duplicated()]
# Out:
#            sku                                               name  \
# 101    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 105    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# ...        ...                                                ...
# 16831  APP2302  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 16833  APP2303  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 18190  PAR0077                         Parrot Bebop Drone 2 Power
# 18308  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18514  PLA0035          Bluetooth Headset Plantronics Explorer 80
#
#                                                     desc    price  \
# 101          MacBook Pro laptop 133 inches (MD101Y / A).  1199.00
# ...

# %%
products.isna().any()
# Out:
# sku            False
# name           False
# desc            True
# price           True
# promo_price     True
# in_stock       False
# type            True
# discount        True
# dtype: bool
